# %% [markdown]
# # **Data Collection Notebook**

# %% [markdown]
# ## Objectives
#
# * Fetch data from Kaggle and save it as raw data.
# * Inspect the data and save it under outputs/datasets/collection
#
# ## Inputs
#
# *   Kaggle JSON file - the authentication token.
#
# ## Outputs
#
# * Generate Dataset:
# - outputs/datasets/collection/HousePricing.csv
# - "outputs/datasets/collection/InheritedHouses.csv"

# %% [markdown]
# ---

# %% [markdown]
# # Install python packages in the notebooks

# %%
# %pip install -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt
# Out:
# Requirement already satisfied: altair==6.1.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: annotated-types==0.7.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: appnope==0.1.4 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 3)) (0.1.4)
# Requirement already satisfied: astor==0.8.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 4)) (0.8.1)
# Requirement already satisfied: asttokens==3.0.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 5)) (3.0.1)
# Requirement already satisfied: attrs==26.1.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 6)) (26.1.0)
# Requirement already satisfied: backcall==0.2.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: base58==2.1.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 8)) (2.1.1)
# Requirement already satisfied: blinker==1.9.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 9)) (1.9.0)
# Requirement already satisfied: cachetools==7.0.6 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 10)) (7.0.6)
# Requirement already satisfied: certifi==2026.4.22 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 11)) (2026.4.22)
# Requirement already satisfied: charset-normalizer==3.4.7 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 12)) (3.4.7)
# Requirement already satisfied: click==8.3.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 13)) (8.3.3)
# Requirement already satisfied: comm==0.2.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 14)) (0.2.3)
# Requirement already satisfied: contourpy==1.3.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 15)) (1.3.3)
# Requirement already satisfied: cycler==0.12.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 16)) (0.12.1)
# Requirement already satisfied: dacite==1.9.2 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 17)) (1.9.2)
# Requirement already satisfied: debugpy==1.8.20 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 18)) (1.8.20)
# Requirement already satisfied: decorator==5.2.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 19)) (5.2.1)
# Requirement already satisfied: entrypoints==0.4 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 20)) (0.4)
# Requirement already satisfied: executing==2.2.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 21)) (2.2.1)
# Requirement already satisfied: feature_engine==1.9.4 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 22)) (1.9.4)
# Requirement already satisfied: filetype==1.2.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 23)) (1.2.0)
# Requirement already satisfied: fonttools==4.62.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 24)) (4.62.1)
# Requirement already satisfied: gitdb==4.0.12 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 25)) (4.0.12)
# Requirement already satisfied: GitPython==3.1.48 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 26)) (3.1.48)
# Requirement already satisfied: htmlmin==0.1.12 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 27)) (0.1.12)
# Requirement already satisfied: idna==3.13 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 28)) (3.13)
# Requirement already satisfied: ImageHash==4.3.2 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 29)) (4.3.2)
# Requirement already satisfied: imbalanced-learn==0.14.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 30)) (0.14.1)
# Requirement already satisfied: importlib_metadata==9.0.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 31)) (9.0.0)
# Requirement already satisfied: importlib_resources==7.1.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 32)) (7.1.0)
# Requirement already satisfied: ipykernel==7.2.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 33)) (7.2.0)
# Requirement already satisfied: ipython==9.13.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 34)) (9.13.0)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 35)) (1.1.1)
# Requirement already satisfied: ipywidgets==8.1.8 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 36)) (8.1.8)
# Requirement already satisfied: jedi==0.19.2 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 37)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 38)) (3.1.6)
# Requirement already satisfied: joblib==1.5.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 39)) (1.5.3)
# Requirement already satisfied: jsonschema==4.26.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 40)) (4.26.0)
# Requirement already satisfied: jsonschema-specifications==2025.9.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 41)) (2025.9.1)
# Requirement already satisfied: jupyter_client==8.8.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 42)) (8.8.0)
# Requirement already satisfied: jupyter_core==5.9.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 43)) (5.9.1)
# Requirement already satisfied: jupyterlab_widgets==3.0.16 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 44)) (3.0.16)
# Requirement already satisfied: kaggle==1.5.12 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 45)) (1.5.12)
# Requirement already satisfied: kiwisolver==1.5.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 46)) (1.5.0)
# Requirement already satisfied: llvmlite==0.45.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 47)) (0.45.1)
# Requirement already satisfied: MarkupSafe==3.0.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 48)) (3.0.3)
# Requirement already satisfied: matplotlib==3.10.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 49)) (3.10.0)
# Requirement already satisfied: matplotlib-inline==0.2.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 50)) (0.2.1)
# Requirement already satisfied: minify_html==0.18.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 51)) (0.18.1)
# Requirement already satisfied: multimethod==1.12 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 52)) (1.12)
# Requirement already satisfied: narwhals==2.20.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 53)) (2.20.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 54)) (1.6.0)
# Requirement already satisfied: networkx==3.6.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 55)) (3.6.1)
# Requirement already satisfied: numba==0.62.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 56)) (0.62.1)
# Requirement already satisfied: numpy==2.3.5 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 57)) (2.3.5)
# Requirement already satisfied: packaging==26.2 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 58)) (26.2)
# Requirement already satisfied: pandas==2.3.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 59)) (2.3.3)
# Requirement already satisfied: parso==0.8.6 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 60)) (0.8.6)
# Requirement already satisfied: patsy==1.0.2 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 61)) (1.0.2)
# Requirement already satisfied: pexpect==4.9.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 62)) (4.9.0)
# Requirement already satisfied: phik==0.12.5 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 63)) (0.12.5)
# Requirement already satisfied: pickleshare==0.7.5 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 64)) (0.7.5)
# Requirement already satisfied: pillow==12.2.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 65)) (12.2.0)
# Requirement already satisfied: pkgutil_resolve_name==1.3.10 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 66)) (1.3.10)
# Requirement already satisfied: platformdirs==4.9.6 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 67)) (4.9.6)
# Requirement already satisfied: plotly==6.7.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 68)) (6.7.0)
# Requirement already satisfied: ppscore==1.3.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 69)) (1.3.1)
# Requirement already satisfied: prompt_toolkit==3.0.52 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 70)) (3.0.52)
# Requirement already satisfied: protobuf==7.34.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 71)) (7.34.1)
# Requirement already satisfied: psutil==7.2.2 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 72)) (7.2.2)
# Requirement already satisfied: ptyprocess==0.7.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 73)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 74)) (0.2.3)
# Requirement already satisfied: puremagic==2.2.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 75)) (2.2.0)
# Requirement already satisfied: pyarrow==24.0.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 76)) (24.0.0)
# Requirement already satisfied: pydantic==2.13.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 77)) (2.13.3)
# Requirement already satisfied: pydantic_core==2.46.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 78)) (2.46.3)
# Requirement already satisfied: pydeck==0.9.2 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 79)) (0.9.2)
# Requirement already satisfied: Pygments==2.20.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 80)) (2.20.0)
# Requirement already satisfied: pyparsing==3.3.2 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 81)) (3.3.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 82)) (2.9.0.post0)
# Requirement already satisfied: python-slugify==8.0.4 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 83)) (8.0.4)
# Requirement already satisfied: pytz==2026.1.post1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 84)) (2026.1.post1)
# Requirement already satisfied: PyWavelets==1.9.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 85)) (1.9.0)
# Requirement already satisfied: PyYAML==6.0.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 86)) (6.0.3)
# Requirement already satisfied: pyzmq==27.1.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 87)) (27.1.0)
# Requirement already satisfied: referencing==0.37.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 88)) (0.37.0)
# Requirement already satisfied: requests==2.33.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 89)) (2.33.1)
# Requirement already satisfied: retrying==1.4.2 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 90)) (1.4.2)
# Requirement already satisfied: rpds-py==0.30.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 91)) (0.30.0)
# Requirement already satisfied: scikit-learn==1.8.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 92)) (1.8.0)
# Requirement already satisfied: scipy==1.16.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 93)) (1.16.3)
# Requirement already satisfied: seaborn==0.13.2 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 94)) (0.13.2)
# Requirement already satisfied: setuptools==82.0.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 95)) (82.0.1)
# Requirement already satisfied: six==1.17.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 96)) (1.17.0)
# Requirement already satisfied: sklearn-compat==0.1.5 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 97)) (0.1.5)
# Requirement already satisfied: smmap==5.0.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 98)) (5.0.3)
# Requirement already satisfied: stack-data==0.6.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 99)) (0.6.3)
# Requirement already satisfied: statsmodels==0.14.6 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 100)) (0.14.6)
# Requirement already satisfied: streamlit==1.56.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 101)) (1.56.0)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 102)) (0.2.0)
# Requirement already satisfied: tenacity==9.1.4 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 103)) (9.1.4)
# Requirement already satisfied: text-unidecode==1.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 104)) (1.3)
# Requirement already satisfied: threadpoolctl==3.6.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 105)) (3.6.0)
# Requirement already satisfied: toml==0.10.2 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 106)) (0.10.2)
# Requirement already satisfied: toolz==1.1.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 107)) (1.1.0)
# Requirement already satisfied: tornado==6.5.5 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 108)) (6.5.5)
# Requirement already satisfied: tqdm==4.67.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 109)) (4.67.3)
# Requirement already satisfied: traitlets==5.14.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 110)) (5.14.3)
# Requirement already satisfied: typeguard==4.5.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 111)) (4.5.1)
# Requirement already satisfied: typing-inspection==0.4.2 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 112)) (0.4.2)
# Requirement already satisfied: typing_extensions==4.15.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 113)) (4.15.0)
# Requirement already satisfied: tzdata==2026.2 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 114)) (2026.2)
# Requirement already satisfied: tzlocal==5.3.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 115)) (5.3.1)
# Requirement already satisfied: urllib3==2.6.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 116)) (2.6.3)
# Requirement already satisfied: validators==0.35.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 117)) (0.35.0)
# Requirement already satisfied: visions==0.8.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 118)) (0.8.1)
# Requirement already satisfied: watchdog==6.0.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 119)) (6.0.0)
# Requirement already satisfied: wcwidth==0.6.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 120)) (0.6.0)
# Requirement already satisfied: wheel==0.47.0 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 121)) (0.47.0)
# Requirement already satisfied: widgetsnbextension==4.0.15 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 122)) (4.0.15)
# Requirement already satisfied: wordcloud==1.9.6 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 123)) (1.9.6)
# Requirement already satisfied: xgboost==2.0.3 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 124)) (2.0.3)
# Requirement already satisfied: ydata-profiling==4.18.4 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 125)) (4.18.4)
# Requirement already satisfied: yellowbrick==1.5 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 126)) (1.5)
# Requirement already satisfied: zipp==3.23.1 in /Users/rimanfarhood/development/pa/HeritageHousePrediction/.venv/lib/python3.12/site-packages (from -r /Users/rimanfarhood/development/pa/HeritageHousePrediction/requirements.txt (line 127)) (3.23.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Change working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/rimanfarhood/development/pa/HeritageHousePrediction/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory.
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/rimanfarhood/development/pa/HeritageHousePrediction'

# %% [markdown]
# # Fetch data from Kaggle

# %% [markdown]
# Install Kaggle package to fetch data

# %%
# %pip install kaggle
# Out:
# Requirement already satisfied: kaggle in ./.venv/lib/python3.12/site-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in ./.venv/lib/python3.12/site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from kaggle) (2026.4.22)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.12/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from kaggle) (2.33.1)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from kaggle) (4.67.3)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.12/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.12/site-packages (from kaggle) (2.6.3)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.12/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->kaggle) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->kaggle) (3.13)
# Note: you may need to restart the kernel to use updated packages.

# %%
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()
! chmod 600 kaggle.json

# %% [markdown]
# Define the Kaggle dataset, and destination folder and download it.

# %%
KaggleDatasetPath = "codeinstitute/housing-prices-data"
DestinationFolder = "inputs/datasets/raw"   
! kaggle datasets download -d {KaggleDatasetPath} -p {DestinationFolder}
# Out:
# Downloading housing-prices-data.zip to inputs/datasets/raw
# 100%|███████████████████████████████████████| 49.6k/49.6k [00:00<00:00, 460kB/s]
# 100%|███████████████████████████████████████| 49.6k/49.6k [00:00<00:00, 457kB/s]

# %% [markdown]
# Unzip the downloaded file, delete the zip file and delete the kaggle.json file

# %%
! unzip {DestinationFolder}/*.zip -d {DestinationFolder} \
  && rm {DestinationFolder}/*.zip \
  && rm kaggle.json
# Out:
# Archive:  inputs/datasets/raw/housing-prices-data.zip
#   inflating: inputs/datasets/raw/house-metadata.txt
#   inflating: inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/house_prices_records.csv
#   inflating: inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/inherited_houses.csv

# %% [markdown]
# ---

# %% [markdown]
# # Load and Inspect Data

# %%
import pandas as pd
df = pd.read_csv("inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/house_prices_records.csv")
inherited_houses = pd.read_csv("inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/inherited_houses.csv")
df.head()
# Out:
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
# 3       961       NaN           NaN           No         216          ALQ
# 4      1145       NaN           4.0           Av         655          GLQ
#
#    BsmtUnfSF  EnclosedPorch  GarageArea GarageFinish  ...  LotFrontage  \
# 0        150            0.0         548          RFn  ...         65.0
# 1        284            NaN         460          RFn  ...         80.0
# 2        434            0.0         608          RFn  ...         68.0
# 3        540            NaN         642          Unf  ...         60.0
# 4        490            0.0         836          RFn  ...         84.0
#
#    MasVnrArea OpenPorchSF  OverallCond  OverallQual  TotalBsmtSF  WoodDeckSF  \
# 0       196.0          61            5            7          856         0.0
# 1         0.0           0            8            6         1262         NaN
# 2       162.0          42            5            7          920         NaN
# 3         0.0          35            5            7          756         NaN
# 4       350.0          84            5            8         1145         NaN
#
#    YearBuilt  YearRemodAdd  SalePrice
# 0       2003          2003     208500
# 1       1976          1976     181500
# 2       2001          2002     223500
# 3       1915          1970     140000
# 4       2000          2000     250000
#
# [5 rows x 24 columns]

# %%
inherited_houses
# Out:
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       896         0             2           No       468.0          Rec
# 1      1329         0             3           No       923.0          ALQ
# 2       928       701             3           No       791.0          GLQ
# 3       926       678             3           No       602.0          GLQ
#
#    BsmtUnfSF  EnclosedPorch  GarageArea GarageFinish  ...  LotArea  \
# 0      270.0              0       730.0          Unf  ...    11622
# 1      406.0              0       312.0          Unf  ...    14267
# 2      137.0              0       482.0          Fin  ...    13830
# 3      324.0              0       470.0          Fin  ...     9978
#
#    LotFrontage MasVnrArea  OpenPorchSF  OverallCond  OverallQual  TotalBsmtSF  \
# 0         80.0        0.0            0            6            5        882.0
# 1         81.0      108.0           36            6            6       1329.0
# 2         74.0        0.0           34            5            5        928.0
# 3         78.0       20.0           36            6            6        926.0
#
#    WoodDeckSF  YearBuilt  YearRemodAdd
# 0         140       1961          1961
# 1         393       1958          1958
# 2         212       1997          1998
# 3         360       1998          1998
#
# [4 rows x 23 columns]

# %% [markdown]
# DataFrame Summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   1stFlrSF       1460 non-null   int64
#  1   2ndFlrSF       1374 non-null   float64
#  2   BedroomAbvGr   1361 non-null   float64
#  3   BsmtExposure   1422 non-null   object
#  4   BsmtFinSF1     1460 non-null   int64
#  5   BsmtFinType1   1315 non-null   object
#  6   BsmtUnfSF      1460 non-null   int64
#  7   EnclosedPorch  136 non-null    float64
#  8   GarageArea     1460 non-null   int64
#  9   GarageFinish   1225 non-null   object
#  10  GarageYrBlt    1379 non-null   float64
#  11  GrLivArea      1460 non-null   int64
#  12  KitchenQual    1460 non-null   object
#  13  LotArea        1460 non-null   int64
#  14  LotFrontage    1201 non-null   float64
#  15  MasVnrArea     1452 non-null   float64
#  16  OpenPorchSF    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  OverallQual    1460 non-null   int64
#  19  TotalBsmtSF    1460 non-null   int64
#  20  WoodDeckSF     155 non-null    float64
#  21  YearBuilt      1460 non-null   int64
#  22  YearRemodAdd   1460 non-null   int64
#  23  SalePrice      1460 non-null   int64
# dtypes: float64(7), int64(13), object(4)
# memory usage: 273.9+ KB

# %%
inherited_houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   1stFlrSF       4 non-null      int64
#  1   2ndFlrSF       4 non-null      int64
#  2   BedroomAbvGr   4 non-null      int64
#  3   BsmtExposure   4 non-null      object
#  4   BsmtFinSF1     4 non-null      float64
#  5   BsmtFinType1   4 non-null      object
#  6   BsmtUnfSF      4 non-null      float64
#  7   EnclosedPorch  4 non-null      int64
#  8   GarageArea     4 non-null      float64
#  9   GarageFinish   4 non-null      object
#  10  GarageYrBlt    4 non-null      float64
#  11  GrLivArea      4 non-null      int64
#  12  KitchenQual    4 non-null      object
#  13  LotArea        4 non-null      int64
#  14  LotFrontage    4 non-null      float64
#  15  MasVnrArea     4 non-null      float64
#  16  OpenPorchSF    4 non-null      int64
#  17  OverallCond    4 non-null      int64
#  18  OverallQual    4 non-null      int64
#  19  TotalBsmtSF    4 non-null      float64
#  20  WoodDeckSF     4 non-null      int64
#  21  YearBuilt      4 non-null      int64
#  22  YearRemodAdd   4 non-null      int64
# dtypes: float64(7), int64(12), object(4)
# memory usage: 868.0+ bytes

# %% [markdown]
# # Push files to Repo

# %%
import os
try:
  # create here your folder
  os.makedirs(name='outputs/datasets/collection')
except Exception as e:
  print(e)

df.to_csv('outputs/datasets/collection/HousePricing.csv', index=False)

inherited_houses.to_csv('outputs/datasets/collection/InheritedHouses.csv',index=False)
# Out:
# [Errno 17] File exists: 'outputs/datasets/collection'
